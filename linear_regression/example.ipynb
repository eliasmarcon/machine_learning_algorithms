# %%
import pandas as pd

from simple_linear_regression import SimpleLinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Disclaimer
#
# ### This is just an example notebook for the self implemented simple linear regression algorithm. It shows most of the implemented functionality for the simple linear regression algorithm.

# %%
df = pd.read_csv('../datasets/advertising.csv')
display(df)
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df['TV'], df['Sales'], train_size = 0.85, test_size = 0.15, random_state = 100)

# %%
lr = SimpleLinearRegression()

# %%
lr.fit(X_train, y_train)

# %%
lr.plot_scatter(title = "TV vs Sales")

# %%
print("Intercept:", lr._intercept)
print("Slope:", lr._slope)
# Out:
# Intercept: 7.036205982844681
# Slope: 0.05404320300582516

# %%
lr.plot_regression_line(title = "TV vs Sales")

# %%
# this plot can only be created after the regression line is trained
lr.plot_residuals(title="TV vs Sales", both = True)

# %%
predictions = lr.predict(X_test)
print(predictions)
# Out:
# [ 7.45774297 19.90929694 14.34284703 18.80141128 20.09844815 18.21234036
#  14.55901984 17.7151429  18.73115511 18.75277239 13.37006938 19.43912107
#  10.07343399 17.18551951 11.74877328 12.12707571 15.12647347 16.23435913
#  15.87226967 13.1376836  18.63928167 14.02939645 17.59624785 16.60185291
#  17.02879422 18.94192361 18.914902   11.10565917 17.02879422 13.68892427]

# %%
MSE = lr.get_metric(predictions, y_test, 'MSE')
print("MSE:", MSE)
# Out:
# MSE: 5.835365428431664

# %%
R_squared = lr.get_metric(predictions, y_test, 'R_squared')
print("R_squared:", R_squared)
# Out:
# R_squared: 0.716787881362585

# %%
# this plot can be created only after the predictions are made and a metric is calculated
lr.plot_testing_and_prediction(title="TV vs Sales")
